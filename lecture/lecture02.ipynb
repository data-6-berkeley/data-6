# %%
# Boilerplate:
from datascience import *
from datascience.predicates import are
import numpy as np
import matplotlib
matplotlib.use('Agg', warn=False)
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Grade weights

# %%
proportions = Table().with_columns(
  "Assignment type", ["Short (M/W) lab", "Long (F) lab", "Homework", "Vitamin", "Midterm", "Final"],
  "Weight",          [.1,                .1,             .2,         .2,        .15,       .25])
proportions.set_format("Weight", PercentFormatter(0))
proportions.barh("Assignment type")
proportions
# Out:
# Assignment type | Weight
# Short (M/W) lab | 10%
# Long (F) lab    | 10%
# Homework        | 20%
# Vitamin         | 20%
# Midterm         | 15%
# Final           | 25%

# %% [markdown]
# ## Are sociology PhDs deadly?

# %%
# The raw data
sociology = Table().with_columns(
  "Year", [1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009],
  "Sociology doctorates awarded (US)", [572, 617, 566, 547, 597, 580, 536, 579, 576, 601, 664],
  "Deaths caused by anticoagulants (US)", [17, 39, 39, 27, 44, 46, 29, 42, 47, 52, 78])

# %%
sociology
# Out:
# Year | Sociology doctorates awarded (US) | Deaths caused by anticoagulants (US)
# 1999 | 572                               | 17
# 2000 | 617                               | 39
# 2001 | 566                               | 39
# 2002 | 547                               | 27
# 2003 | 597                               | 44
# 2004 | 580                               | 46
# 2005 | 536                               | 29
# 2006 | 579                               | 42
# 2007 | 576                               | 47
# 2008 | 601                               | 52
# ... (1 rows omitted)

# %%
sociology.plot("Year")

# %% [markdown]
# ### More complicated plots take some tuning to get right

# %%
fig, ax1 = plots.subplots()
ax1.plot(sociology.column(0), sociology.column(1), 'b-')
ax1.set_xlabel('Year')
ax1.set_ylabel('Doctorates', color='b')
ax1.tick_params('y', colors='b')
ax1.grid(False, axis='y')

ax2 = ax1.twinx()
ax2.plot(sociology.column(0), sociology.column(2), 'r-')
ax2.set_ylabel('Anticoagulant deaths', color='r')
ax2.tick_params('y', colors='r')
ax2.grid(False, axis='y')

fig.tight_layout()
plots.show()

# %% [markdown]
# ### Association?

# %%
sociology.scatter(1, 2)
