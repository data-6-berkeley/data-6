# %%
from datascience import *
import numpy as np

import matplotlib
matplotlib.use('Agg', warn=False)
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
ca = make_array(1485053, 2377549, 3426861)
years = np.arange(1900, 1920+10, 10)
ca_population = Table().with_columns(
    "Year", years,
    "Population", ca,
    "Average temp", make_array(2000000, 2000000.1, 3000000.2))
ca_population
# Out:
# Year | Population | Average temp
# 1900 | 1485053    | 2e+06
# 1910 | 2377549    | 2e+06
# 1920 | 3426861    | 3e+06

# %%
ca_population.barh("Population", make_array("Year", "Average temp"))

# %%
ca_population.barh("Year", "Population")
