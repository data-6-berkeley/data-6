# %%
from datascience import *
import numpy as np

import matplotlib
matplotlib.use('Agg', warn=False)
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
Table.interactive_plots()

# %% [markdown]
# ## Modifying a table

# %%
## Retrieving table info: num_rows, num_columns, labels
housing = Table().read_table("nyc_housing.csv")
housing

# %%
## Modifying the table: select, take, drop, relabel
housing

# %%
## How do I find the housing complex with the most residential units? The least?
housing.sort("res_units")...

# %%
## Bonus question: Notice that many of the columns have values that are strings instead of integers. How do I fix that?
for i in ...:
    ...

# %% [markdown]
# ## More histograms

# %%
movies_gross = Table.read_table("https://raw.githubusercontent.com/data-8r/textbook/gh-pages/notebooks/top_movies.csv")
movies_gross

# %%
## Let's analyze the years using a histogram with a density scale. From last time:
movies_gross.bin("Year", bins= np.arange(1920, 2030, 10))

# %%
## How many movies in the dataset were created between 1960 and 1970? Hover over the bar for more info. 
movies_gross.hist("Year", bins = np.arange(1920, 2030, 10))

# %% [markdown]
# ## Filtering tables

# %%
# What movies were made in 1999?
movies_gross.where(...)

# %%
## Do movies today make more money than those made before a specific date?
after_1970 = ...
before_1970 = ...

# %%
# Do they have a different distribution of adjusted gross?
min_gross = min(movies_gross.column("Gross (Adjusted)"))
max_gross = max(movies_gross.column("Gross (Adjusted)"))
bins = np.arange(min_gross, max_gross + 1000000, 50000000)

# %%
print("This is the adjusted gross for movies before 1970 (below).")
...
print("This is the adjusted gross for movies after 1970 (below).")
...
